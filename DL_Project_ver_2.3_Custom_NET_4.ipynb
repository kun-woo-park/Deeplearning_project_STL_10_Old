# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import matplotlib.pyplot as plt
import numpy as np
import os
import time
import shutil
import torch.distributed as dist
import math
from PIL import Image
from tqdm import tqdm
from glob import glob
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
from typing import Type, Any, Callable, Union, List, Optional
from torch import Tensor
from torch.hub import load_state_dict_from_url
from torch.utils.data.dataloader import default_collate
from torch.utils.data.sampler import BatchSampler
from collections.abc import Mapping, Sequence

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
train_path_path= f"{os.getcwd()}/data/split_train/train"
test_path_path= f"{os.getcwd()}/data/split_train/val"

# %%
batch_size=128
num_gpus=4
num_workers=8
lr=0.001

# %%
normalize = transforms.Normalize(mean=[0.507, 0.487, 0.441],
                                     std=[0.267, 0.256, 0.276])

# %%
dataset = datasets.ImageFolder(
        train_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
            
        transforms.RandomResizedCrop(80),
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
for _ in range (19):
    aug_data = datasets.ImageFolder(
        train_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
            
        transforms.RandomResizedCrop(80),
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
    dataset=torch.utils.data.ConcatDataset([dataset,aug_data])
valset = datasets.ImageFolder(
        test_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
            
        transforms.RandomResizedCrop(80),
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
for _ in range (19):
    aug_data = datasets.ImageFolder(
        test_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
            
        transforms.RandomResizedCrop(80),
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
    valset=torch.utils.data.ConcatDataset([valset,aug_data])

train_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=True,
        num_workers=8, pin_memory=True,drop_last=True)

test_loader = torch.utils.data.DataLoader(
        valset, batch_size=batch_size, shuffle=True,
        num_workers=8, pin_memory=True,drop_last=True)

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.layer_1 = nn.Conv2d(in_channels=3,out_channels=64,kernel_size=5,
                                 stride=2,padding=3)
        self.act_1 = nn.LeakyReLU(0.1)
        self.conv2_bn1 = nn.BatchNorm2d(64)
        self.max_1=nn.MaxPool2d(2,2)
        
        self.layer_2 = nn.Conv2d(in_channels=64,out_channels=128,kernel_size=4,
                                 stride=1,padding=2)
        self.act_2 = nn.LeakyReLU(0.1)
        self.conv2_bn2 = nn.BatchNorm2d(128)
        
        self.layer_3 = nn.Conv2d(in_channels=128,out_channels=128,kernel_size=4,
                                 stride=1,padding=2)
        self.act_3 = nn.LeakyReLU(0.1)
        self.conv2_bn3 = nn.BatchNorm2d(128)
        
        self.layer_4 = nn.Conv2d(in_channels=128,out_channels=128,kernel_size=1,
                                 stride=1)
        self.act_4 = nn.LeakyReLU(0.1)
        self.conv2_bn4 = nn.BatchNorm2d(128)
        
        self.max_1=nn.MaxPool2d(2,2)
        
        self.layer_5 = nn.Conv2d(in_channels=128,out_channels=256,kernel_size=3,
                                 stride=1,padding=2)
        self.act_5 = nn.LeakyReLU(0.1)
        self.conv2_bn5 = nn.BatchNorm2d(256)
        
        self.layer_6 = nn.Conv2d(in_channels=256,out_channels=256,kernel_size=3,
                                 stride=1,padding=2)
        self.act_6 = nn.LeakyReLU(0.1)
        self.conv2_bn6 = nn.BatchNorm2d(256)
        
        self.layer_7 = nn.Conv2d(in_channels=256,out_channels=256,kernel_size=1,
                                 stride=1)
        self.act_7 = nn.LeakyReLU(0.1)
        self.conv2_bn7 = nn.BatchNorm2d(256)
        
        self.max_2=nn.MaxPool2d(2,2)
        
        self.layer_8 = nn.Conv2d(in_channels=256,out_channels=512,kernel_size=2,
                                 stride=1,padding=2)
        self.act_8 = nn.LeakyReLU(0.1)
        self.conv2_bn8 = nn.BatchNorm2d(512)
        
        
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        
        self.fc_layer_1 = nn.Linear(512,10)
        self.act_9 = nn.LeakyReLU(0.1)
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        
        

    def forward(self, x):
        out = self.layer_1(x)
        out = self.act_1(out)
        for module in list(self.modules())[2:-2]:
            out = module(out)
        out = torch.flatten(out,1)
        for module in list(self.modules())[-2:]:
            out = module(out)
        return out

# %%
model = Model()
model = model.cuda()
criterion = nn.CrossEntropyLoss().cuda()

# %%
# for name, param in model.named_parameters():
#     if param.requires_grad:
#         print (name, param.data)

# %%
from torchsummary import summary
summary(model,(3,96,96))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 49, 49]           4,864
#          LeakyReLU-2           [-1, 64, 49, 49]               0
#          LeakyReLU-3           [-1, 64, 49, 49]               0
#        BatchNorm2d-4           [-1, 64, 49, 49]             128
#          MaxPool2d-5           [-1, 64, 24, 24]               0
#             Conv2d-6          [-1, 128, 25, 25]         131,200
#          LeakyReLU-7          [-1, 128, 25, 25]               0
#        BatchNorm2d-8          [-1, 128, 25, 25]             256
#             Conv2d-9          [-1, 128, 26, 26]         262,272
#         LeakyReLU-10          [-1, 128, 26, 26]               0
#       BatchNorm2d-11          [-1, 128, 26, 26]             256
#            Conv2d-12          [-1, 128, 26, 26]          16,512
#         LeakyReLU-13          [-1, 128, 26, 26]               0
#       BatchNorm2d-14          [-1, 128, 26, 26]             256
#            Conv2d-15          [-1, 256, 28, 28]         295,168
#         LeakyReLU-16          [-1, 256, 28, 28]               0
#       BatchNorm2d-17          [-1, 256, 28, 28]             512
#            Conv2d-18          [-1, 256, 30, 30]         590,080
#         LeakyReLU-19          [-1, 256, 30, 30]               0
#       BatchNorm2d-20          [-1, 256, 30, 30]             512
#            Conv2d-21          [-1, 256, 30, 30]          65,792
#         LeakyReLU-22          [-1, 256, 30, 30]               0
#       BatchNorm2d-23          [-1, 256, 30, 30]             512
#         MaxPool2d-24          [-1, 256, 15, 15]               0
#            Conv2d-25          [-1, 512, 18, 18]         524,800
#         LeakyReLU-26          [-1, 512, 18, 18]               0
#       BatchNorm2d-27          [-1, 512, 18, 18]           1,024
# AdaptiveAvgPool2d-28            [-1, 512, 1, 1]               0
#            Linear-29                   [-1, 10]           5,130
#         LeakyReLU-30                   [-1, 10]               0
# ================================================================
# Total params: 1,899,274
# Trainable params: 1,899,274
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.11
# Forward/backward pass size (MB): 30.14
# Params size (MB): 7.25
# Estimated Total Size (MB): 37.49
# ----------------------------------------------------------------

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30)

# %%
saving_path="/home/jupyter-deeplearning/res_model"
trn_loss_list = []
val_loss_list = []
val_acc_list = []
total_epoch=120
model_char="2.0"
model_name=""
patience=10
start_early_stop_check=0
saving_start_epoch=10

for epoch in range(total_epoch):
    trn_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        if torch.cuda.is_available():
            inputs=inputs.cuda()
            labels=labels.cuda()
        # grad init
        optimizer.zero_grad()
        # forward propagation
        output= model(inputs)
        # calculate loss
        loss=criterion(output, labels)
        # back propagation 
        loss.backward()
        # weight update
        optimizer.step()
        
        # trn_loss summary
        trn_loss += loss.item()
        # del (memory issue)
        del loss
        del output
    with torch.no_grad():
        val_loss = 0.0
        cor_match = 0
        for j, val in enumerate(test_loader):
            val_x, val_label = val
            if torch.cuda.is_available():
                val_x = val_x.cuda()
                val_label =val_label.cuda()
            val_output = model(val_x)
            v_loss = criterion(val_output, val_label)
            val_loss += v_loss
            _, predicted=torch.max(val_output,1)
            cor_match+=np.count_nonzero(predicted.cpu().detach()==val_label.cpu().detach())
    del val_output
    del v_loss
    del predicted
    
    scheduler.step()
    
    
    
    trn_loss_list.append(trn_loss/len(train_loader))
    val_loss_list.append(val_loss/len(test_loader))
    val_acc=cor_match/(len(test_loader)*batch_size)
    val_acc_list.append(val_acc)
    now = time.localtime()
    print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))

    print("epoch: {}/{} | trn loss: {:.4f} | val loss: {:.4f} | val accuracy: {:.4f}% \n".format(
                epoch+1, total_epoch, trn_loss / len(train_loader), val_loss / len(test_loader), val_acc*100
            ))
    
    
    if epoch+1>2:
        if val_loss_list[-1]>val_loss_list[-2]:
            start_early_stop_check=1
    else:
        val_loss_min=val_loss_list[-1]
        
    if start_early_stop_check:
        early_stop_temp=val_loss_list[-patience:]
        if all(early_stop_temp[i]<early_stop_temp[i+1] for i in range (len(early_stop_temp)-1)):
            print("Early stop!")
            break
            
    if epoch+1>saving_start_epoch:
        if val_loss_list[-1]<val_loss_min:
            if os.path.isfile(model_name):
                os.remove(model_name)
            val_loss_min=val_loss_list[-1]
            model_name=saving_path+"Custom_model_"+model_char+"_{:.3f}".format(val_loss_min)
            torch.save(model, model_name)
            print("Model replaced and saved as ",model_name)
# Out:
# 2020/11/14 21:47:20
# epoch: 1/120 | trn loss: 1.8282 | val loss: 1.6982 | val accuracy: 37.4249%
#
# 2020/11/14 21:48:08
# epoch: 2/120 | trn loss: 1.5663 | val loss: 1.5164 | val accuracy: 45.3075%
#
# 2020/11/14 21:48:56
# epoch: 3/120 | trn loss: 1.4191 | val loss: 1.4308 | val accuracy: 48.4075%
#
# 2020/11/14 21:49:44
# epoch: 4/120 | trn loss: 1.3046 | val loss: 1.3361 | val accuracy: 52.1985%
#
# 2020/11/14 21:50:32
# epoch: 5/120 | trn loss: 1.2045 | val loss: 1.2884 | val accuracy: 53.9113%
#
# 2020/11/14 21:51:19
# epoch: 6/120 | trn loss: 1.1243 | val loss: 1.2464 | val accuracy: 55.5990%
#
# 2020/11/14 21:52:07
# epoch: 7/120 | trn loss: 1.0498 | val loss: 1.1992 | val accuracy: 57.5671%
#
# 2020/11/14 21:52:55
# epoch: 8/120 | trn loss: 0.9842 | val loss: 1.1515 | val accuracy: 59.2598%
#
# 2020/11/14 21:54:03
# epoch: 9/120 | trn loss: 0.9295 | val loss: 1.1301 | val accuracy: 60.3766%
#
# 2020/11/14 21:54:53
# epoch: 10/120 | trn loss: 0.8730 | val loss: 1.1453 | val accuracy: 60.1312%
#
# 2020/11/14 21:55:42
# epoch: 11/120 | trn loss: 0.8340 | val loss: 1.1230 | val accuracy: 61.2430%
#
# Model replaced and saved as  /home/jupyter-deeplearning/res_modelCustom_model_2.0_1
#
# 2020/11/14 23:16:05
# epoch: 108/120 | trn loss: 0.2106 | val loss: 1.1011 | val accuracy: 68.5296%
#
# 2020/11/14 23:16:55
# epoch: 109/120 | trn loss: 0.2093 | val loss: 1.0803 | val accuracy: 68.6699%
#
# 2020/11/14 23:17:44
# epoch: 110/120 | trn loss: 0.2125 | val loss: 1.0839 | val accuracy: 68.6599%
#
# 2020/11/14 23:18:33
# epoch: 111/120 | trn loss: 0.2130 | val loss: 1.0923 | val accuracy: 68.7550%
#
# 2020/11/14 23:19:22
# epoch: 112/120 | trn loss: 0.2104 | val loss: 1.1021 | val accuracy: 68.4245%
#
# 2020/11/14 23:20:10
# epoch: 113/120 | trn loss: 0.2083 | val loss: 1.0915 | val accuracy: 68.8902%
#
# 2020/11/14 23:21:00
# epoch: 114/120 | trn loss: 0.2139 | val loss: 1.0832 | val accuracy: 68.7500%
#
# 2020/11/14 23:21:48
# epoch: 115/120 | trn loss: 0.2113 | val loss: 1.0931 | val accuracy: 68.8852%
#
# 2020/11/14 23:22:36
# epoch: 116/120 | trn loss: 0.2123 | val loss: 1.0946 | val accuracy: 68.7951%
#
# 2020/11/14 23:23:24
# epoch: 117/120 | trn loss: 0.2094 | val loss: 1.0876 | val accuracy: 68.6048%
#
# 2020/11/14 23:24:11
# epoch: 118/120 | trn loss: 0.2099 | val loss: 1.0828 | val accuracy: 68.9754%
#
# 2020/11/14 23:24:59
# epoch: 119/120 | trn loss: 0.2091 | val loss: 1.0817 | val accuracy: 68.6999%
#
# 2020/11/14 23:25:46
# epoch: 120/120 | trn loss: 0.2148 | val loss: 1.0936 | val accuracy: 68.5397%

# %%
dataset = datasets.ImageFolder(
        train_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
            
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
for _ in range (19):
    aug_data = datasets.ImageFolder(
        train_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
            
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
    dataset=torch.utils.data.ConcatDataset([dataset,aug_data])
valset = datasets.ImageFolder(
        test_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
            
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
for _ in range (19):
    aug_data = datasets.ImageFolder(
        test_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
            
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
    valset=torch.utils.data.ConcatDataset([valset,aug_data])

train_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=True,
        num_workers=8, pin_memory=True,drop_last=True)

test_loader = torch.utils.data.DataLoader(
        valset, batch_size=batch_size, shuffle=True,
        num_workers=8, pin_memory=True,drop_last=True)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20)

# %%
#fine tuning

total_epoch=80
model_char="2.0"
model_name=""
patience=10
start_early_stop_check=0
saving_start_epoch=10

for epoch in range(total_epoch):
    trn_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        if torch.cuda.is_available():
            inputs=inputs.cuda()
            labels=labels.cuda()
        # grad init
        optimizer.zero_grad()
        # forward propagation
        output= model(inputs)
        # calculate loss
        loss=criterion(output, labels)
        # back propagation 
        loss.backward()
        # weight update
        optimizer.step()
        
        # trn_loss summary
        trn_loss += loss.item()
        # del (memory issue)
        del loss
        del output
    with torch.no_grad():
        val_loss = 0.0
        cor_match = 0
        for j, val in enumerate(test_loader):
            val_x, val_label = val
            if torch.cuda.is_available():
                val_x = val_x.cuda()
                val_label =val_label.cuda()
            val_output = model(val_x)
            v_loss = criterion(val_output, val_label)
            val_loss += v_loss
            _, predicted=torch.max(val_output,1)
            cor_match+=np.count_nonzero(predicted.cpu().detach()==val_label.cpu().detach())
    del val_output
    del v_loss
    del predicted
    
    scheduler.step()
    
    
    
    trn_loss_list.append(trn_loss/len(train_loader))
    val_loss_list.append(val_loss/len(test_loader))
    val_acc=cor_match/(len(test_loader)*batch_size)
    val_acc_list.append(val_acc)
    now = time.localtime()
    print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))

    print("epoch: {}/{} | trn loss: {:.4f} | val loss: {:.4f} | val accuracy: {:.4f}% \n".format(
                epoch+1, total_epoch, trn_loss / len(train_loader), val_loss / len(test_loader), val_acc*100
            ))
    
    
    if epoch+1>2:
        if val_loss_list[-1]>val_loss_list[-2]:
            start_early_stop_check=1
    else:
        val_loss_min=val_loss_list[-1]
        
    if start_early_stop_check:
        early_stop_temp=val_loss_list[-patience:]
        if all(early_stop_temp[i]<early_stop_temp[i+1] for i in range (len(early_stop_temp)-1)):
            print("Early stop!")
            break
            
    if epoch+1>saving_start_epoch:
        if val_loss_list[-1]<val_loss_min:
            if os.path.isfile(model_name):
                os.remove(model_name)
            val_loss_min=val_loss_list[-1]
            model_name="Custom_model_"+model_char+"_{:.3f}".format(val_loss_min)
            torch.save(model, model_name)
            print("Model replaced and saved as ",model_name)
# Out:
# 2020/11/14 23:26:47
# epoch: 1/80 | trn loss: 0.0977 | val loss: 1.0247 | val accuracy: 73.1220%
#
# 2020/11/14 23:27:47
# epoch: 2/80 | trn loss: 0.0854 | val loss: 1.0106 | val accuracy: 73.6829%
#
# 2020/11/14 23:28:47
# epoch: 3/80 | trn loss: 0.0762 | val loss: 1.0275 | val accuracy: 73.2923%
#
# 2020/11/14 23:29:47
# epoch: 4/80 | trn loss: 0.0740 | val loss: 1.0089 | val accuracy: 73.2622%
#
# 2020/11/14 23:30:48
# epoch: 5/80 | trn loss: 0.0711 | val loss: 1.0782 | val accuracy: 73.0719%
#
# 2020/11/14 23:31:48
# epoch: 6/80 | trn loss: 0.0699 | val loss: 1.0904 | val accuracy: 73.2222%
#
# 2020/11/14 23:32:48
# epoch: 7/80 | trn loss: 0.0659 | val loss: 1.0821 | val accuracy: 73.6929%
#
# 2020/11/14 23:33:48
# epoch: 8/80 | trn loss: 0.0670 | val loss: 1.0917 | val accuracy: 73.2622%
#
# 2020/11/14 23:34:48
# epoch: 9/80 | trn loss: 0.0615 | val loss: 1.1714 | val accuracy: 72.9617%
#
# 2020/11/14 23:35:48
# epoch: 10/80 | trn loss: 0.0597 | val loss: 1.0960 | val accuracy: 72.9567%
#
# 2020/11/14 23:36:49
# epoch: 11/80 | trn loss: 0.0615 | val loss: 1.0094 | val accuracy: 74.9900%
#
# Model replaced and saved as  Custom_model_2.0_1.009
# 2020/11/14 23:37:49
# epoch: 12/80 | trn loss: 0.0617 | val loss: 1.1366 | val accuracy: 72.6362%
#
# 2020/11/14 23:38:49
# epoch: 13/80 | trn loss: 0.0585 | val loss: 1.0471 | val accuracy: 74.3039%
#
# 2020/11/14 23:39:49
# epoch: 14/80 | trn loss: 0.0532 | val loss: 1.0925 | val accuracy: 73.0068%
#
# 2020/11/14 23:40:49
# epoch: 15/80 | trn loss: 0.0567 | val loss: 1.1157 | val accuracy: 73.1270%
#
# 2020/11/14 23:41:50
# epoch: 16/80 | trn loss: 0.0633 | val loss: 1.1655 | val accuracy: 72.6713%
#
# 2020/11/14 23:42:50
# epoch: 17/80 | trn loss: 0.0544 | val loss: 1.1274 | val accuracy: 72.8766%
#
# 2020/11/14 23:43:50
# epoch: 18/80 | trn loss: 0.0548 | val loss: 1.1176 | val accuracy: 73.2923%
#
# 2020/11/14 23:44:50
# epoch: 19/80 | trn loss: 0.0548 | val loss: 1.1477 | val accuracy: 72.7714%
#
# 2020/11/14 23:45:51
# epoch: 20/80 | trn loss: 0.0511 | val loss: 1.0801 | val accuracy: 73.9884%
#
# 2020/11/14 23:46:51
# epoch: 21/80 | trn loss: 0.0122 | val loss: 0.9888 | val accuracy: 75.9866%
#
# Model replaced and saved as  Custom_model_2.0_0.989
# 2020/11/14 23:47:51
# epoch: 22/80 | trn loss: 0.0053 | val loss: 0.9711 | val accuracy: 76.8329%
#
# Model replaced and saved as  Custom_model_2.0_0.971
# 2020/11/14 23:48:51
# epoch: 23/80 | trn loss: 0.0039 | val loss: 0.9733 | val accuracy: 76.7177%
#
# 2020/11/14 23:49:51
# epoch: 24/80 | trn loss: 0.0036 | val loss: 0.9484 | val accuracy: 76.7829%
#
# Model replaced and saved as  Custom_model_2.0_0.948
# 2020/11/14 23:50:52
# epoch: 25/80 | trn loss: 0.0029 | val loss: 0.9519 | val accuracy: 77.1585%
#
# 2020/11/14 23:51:52
# epoch: 26/80 | trn loss: 0.0028 | val loss: 0.9387 | val accuracy: 76.7478%
#
# Model replaced and saved as  Custom_model_2.0_0.939
# 2020/11/14 23:52:52
# epoch: 27/80 | trn loss: 0.0030 | val loss: 0.9505 | val accuracy: 76.8480%
#
# 2020/11/14 23:53:54
# epoch: 28/80 | trn loss: 0.0032 | val loss: 0.9218 | val accuracy: 76.3021%
#
# Model replaced and saved as  Custom_model_2.0_0.922
# 2020/11/14 23:54:54
# epoch: 29/80 | trn loss: 0.0031 | val loss: 0.9341 | val accuracy: 76.7879%
#
# 2020/11/14 23:55:54
# epoch: 30/80 | trn loss: 0.0032 | val loss: 0.9274 | val accuracy: 75.9816%
#
# 2020/11/14 23:56:54
# epoch: 31/80 | trn loss: 0.0030 | val loss: 0.9208 | val accuracy: 76.1869%
#
# Model replaced and saved as  Custom_model_2.0_0.921
# 2020/11/14 23:57:54
# epoch: 32/80 | trn loss: 0.0033 | val loss: 0.8970 | val accuracy: 76.7027%
#
# Model replaced and saved as  Custom_model_2.0_0.897
# 2020/11/14 23:58:54
# epoch: 33/80 | trn loss: 0.0033 | val loss: 0.9004 | val accuracy: 76.3772%
#
# 2020/11/14 23:59:54
# epoch: 34/80 | trn loss: 0.0037 | val loss: 0.9360 | val accuracy: 76.0266%
#
# 2020/11/15 00:00:54
# epoch: 35/80 | trn loss: 0.0039 | val loss: 0.9138 | val accuracy: 76.0968%
#
# 2020/11/15 00:01:55
# epoch: 36/80 | trn loss: 0.0030 | val loss: 0.8949 | val accuracy: 76.3572%
#
# Model replaced and saved as  Custom_model_2.0_0.895
# 2020/11/15 00:02:55
# epoch: 37/80 | trn loss: 0.0033 | val loss: 0.9052 | val accuracy: 76.1268%
#
# 2020/11/15 00:03:54
# epoch: 38/80 | trn loss: 0.0034 | val loss: 0.8659 | val accuracy: 76.9131%
#
# Model replaced and saved as  Custom_model_2.0_0.866
# 2020/11/15 00:04:55
# epoch: 39/80 | trn loss: 0.0041 | val loss: 0.8759 | val accuracy: 76.6176%
#
# 2020/11/15 00:05:55
# epoch: 40/80 | trn loss: 0.0036 | val loss: 0.8861 | val accuracy: 76.4623%
#
# 2020/11/15 00:06:55
# epoch: 41/80 | trn loss: 0.0025 | val loss: 0.8531 | val accuracy: 76.9281%
#
# Model replaced and saved as  Custom_model_2.0_0.853
# 2020/11/15 00:07:55
# epoch: 42/80 | trn loss: 0.0021 | val loss: 0.8541 | val accuracy: 77.0683%
#
# 2020/11/15 00:08:55
# epoch: 43/80 | trn loss: 0.0019 | val loss: 0.8460 | val accuracy: 77.2887%
#
# Model replaced and saved as  Custom_model_2.0_0.846
# 2020/11/15 00:09:55
# epoch: 44/80 | trn loss: 0.0018 | val loss: 0.8362 | val accuracy: 77.2386%
#
# Model replaced and saved as  Custom_model_2.0_0.836
# 2020/11/15 00:10:57
# epoch: 45/80 | trn loss: 0.0018 | val loss: 0.8550 | val accuracy: 76.8329%
#
# 2020/11/15 00:11:56
# epoch: 46/80 | trn loss: 0.0018 | val loss: 0.8518 | val accuracy: 76.7228%
#
# 2020/11/15 00:12:56
# epoch: 47/80 | trn loss: 0.0018 | val loss: 0.8404 | val accuracy: 76.9531%
#
# 2020/11/15 00:13:56
# epoch: 48/80 | trn loss: 0.0018 | val loss: 0.8458 | val accuracy: 76.8980%
#
# 2020/11/15 00:14:55
# epoch: 49/80 | trn loss: 0.0018 | val loss: 0.8501 | val accuracy: 77.0132%
#
#
# 2020/11/15 00:37:37
# epoch: 72/80 | trn loss: 0.0018 | val loss: 0.8231 | val accuracy: 76.8830%
#
# 2020/11/15 00:38:35
# epoch: 73/80 | trn loss: 0.0018 | val loss: 0.8251 | val accuracy: 76.7728%
#
# 2020/11/15 00:39:33
# epoch: 74/80 | trn loss: 0.0017 | val loss: 0.8141 | val accuracy: 77.3588%
#
# 2020/11/15 00:40:31
# epoch: 75/80 | trn loss: 0.0018 | val loss: 0.8126 | val accuracy: 77.1635%
# 2020/11/15 00:41:29
# epoch: 76/80 | trn loss: 0.0018 | val loss: 0.8273 | val accuracy: 76.8980%
#
# 2020/11/15 00:42:27
# epoch: 77/80 | trn loss: 0.0018 | val loss: 0.8153 | val accuracy: 77.2436%
#
# 2020/11/15 00:43:25
# epoch: 78/80 | trn loss: 0.0018 | val loss: 0.8102 | val accuracy: 77.1985%
#
# Model replaced and saved as  Custom_model_2.0_0.810
# 2020/11/15 00:44:23
# epoch: 79/80 | trn loss: 0.0018 | val loss: 0.8251 | val accuracy: 76.8880%
#
# 2020/11/15 00:45:21
# epoch: 80/80 | trn loss: 0.0018 | val loss: 0.8026 | val accuracy: 77.5190%
#
# Model replaced and saved as  Custom_model_2.0_0.803

# %%
plt.figure(figsize=(15,15))
plt.ylabel("val_accuracy")
plt.xlabel("epoch")
plt.plot(val_acc_list)
plt.grid()

# %%
val_acc_list=np.array(val_acc_list)
np.savetxt("ver_2.0.txt", val_acc_list, delimiter=',')

# %% [markdown]
# ### Evaluation

# %%
import torch
import pandas as pd
import argparse
import time
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader

# %%
model.eval()
# Out:
# Model(
#   (layer_1): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2), padding=(3, 3))
#   (act_1): LeakyReLU(negative_slope=0.1)
#   (conv2_bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (max_1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (layer_2): Conv2d(64, 128, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#   (act_2): LeakyReLU(negative_slope=0.1)
#   (conv2_bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer_3): Conv2d(128, 128, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#   (act_3): LeakyReLU(negative_slope=0.1)
#   (conv2_bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer_4): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#   (act_4): LeakyReLU(negative_slope=0.1)
#   (conv2_bn4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer_5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (act_5): LeakyReLU(negative_slope=0.1)
#   (conv2_bn5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer_6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (act_6): LeakyReLU(negative_slope=0.1)
#   (conv2_bn6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer_7): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#   (act_7): LeakyReLU(negative_slope=0.1)
#   (conv2_bn7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (max_2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (layer_8): Conv2d(256, 512, kernel_size=(2, 2), stride=(1, 1), padding=(2, 2))
#   (act_8): LeakyReLU(negative_slope=0.1)
#   (conv2_bn8): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc_layer_1): Linear(in_features=512, out_features=10, bias=True)
#   (act_9): LeakyReLU(negative_slope=0.1)
# )

# %%
normalize = transforms.Normalize(mean=[0.507, 0.487, 0.441],
                                     std=[0.267, 0.256, 0.276])
test_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize
    ])

# %%
test_dataset = torchvision.datasets.ImageFolder('./data/test', transform=test_transform)

# %%
test_loader = DataLoader(test_dataset, batch_size=batch_size, num_workers=4, shuffle=False)

# %%
Category = []
for input, _ in test_loader:
    input = input.cuda()
    output = model(input)
    output = torch.argmax(output, dim=1)
    Category = Category + output.tolist()

# %%
Id = list(range(0, 8000))
samples = {
   'Id': Id,
   'Category': Category 
}
df = pd.DataFrame(samples, columns=['Id', 'Category'])

df.to_csv('submission_2.0_2.csv', index=False)
print('Done!!')
# Out:
# Done!!
