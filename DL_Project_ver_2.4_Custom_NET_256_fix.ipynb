# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import matplotlib.pyplot as plt
import numpy as np
import os
import time
import shutil
import torch.distributed as dist
import math
from PIL import Image
from tqdm import tqdm
from glob import glob
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
from typing import Type, Any, Callable, Union, List, Optional
from torch import Tensor
from torch.hub import load_state_dict_from_url
from torch.utils.data.dataloader import default_collate
from torch.utils.data.sampler import BatchSampler
from collections.abc import Mapping, Sequence

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %%
train_path_path= "../data/split_train/train"
test_path_path= "../data/split_train/val"

# %%
batch_size=256
num_gpus=4
num_workers=8
lr=0.001

# %%
normalize = transforms.Normalize(mean=[0.507, 0.487, 0.441],
                                     std=[0.267, 0.256, 0.276])

# %%
dataset = datasets.ImageFolder(
        train_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
            
        transforms.RandomResizedCrop(70),
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
for _ in range (19):
    aug_data = datasets.ImageFolder(
        train_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
            
        transforms.RandomResizedCrop(70),
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
    dataset=torch.utils.data.ConcatDataset([dataset,aug_data])
valset = datasets.ImageFolder(
        test_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
            
        transforms.RandomResizedCrop(70),
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
for _ in range (19):
    aug_data = datasets.ImageFolder(
        test_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
            
        transforms.RandomResizedCrop(70),
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
    valset=torch.utils.data.ConcatDataset([valset,aug_data])

train_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=True,
        num_workers=8, pin_memory=True,drop_last=True)

test_loader = torch.utils.data.DataLoader(
        valset, batch_size=batch_size, shuffle=True,
        num_workers=8, pin_memory=True,drop_last=True)

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.layer_1 = nn.Conv2d(in_channels=3,out_channels=64,kernel_size=7,
                                 stride=2,padding=3)
        self.act_1 = nn.LeakyReLU(0.1)
        self.conv2_bn1 = nn.BatchNorm2d(64)
        self.max_1=nn.MaxPool2d(2,2)
        
        self.layer_2 = nn.Conv2d(in_channels=64,out_channels=64,kernel_size=3,
                                 stride=1,padding=2)
        self.act_2 = nn.LeakyReLU(0.1)
        self.conv2_bn2 = nn.BatchNorm2d(64)
        
        self.layer_3 = nn.Conv2d(in_channels=64,out_channels=128,kernel_size=3,
                                 stride=1,padding=2)
        self.act_3 = nn.LeakyReLU(0.1)
        self.conv2_bn3 = nn.BatchNorm2d(128)
        
        self.layer_4 = nn.Conv2d(in_channels=128,out_channels=128,kernel_size=3,
                                 stride=1)
        self.act_4 = nn.LeakyReLU(0.1)
        self.conv2_bn4 = nn.BatchNorm2d(128)
        
        self.max_1=nn.MaxPool2d(2,2)
        
        self.layer_5 = nn.Conv2d(in_channels=128,out_channels=128,kernel_size=3,
                                 stride=1,padding=2)
        self.act_5 = nn.LeakyReLU(0.1)
        self.conv2_bn5 = nn.BatchNorm2d(128)
        
        self.layer_6 = nn.Conv2d(in_channels=128,out_channels=256,kernel_size=3,
                                 stride=1,padding=2)
        self.act_6 = nn.LeakyReLU(0.1)
        self.conv2_bn6 = nn.BatchNorm2d(256)
        
        self.layer_7 = nn.Conv2d(in_channels=256,out_channels=256,kernel_size=3,
                                 stride=1)
        self.act_7 = nn.LeakyReLU(0.1)
        self.conv2_bn7 = nn.BatchNorm2d(256)
        
        self.max_2=nn.MaxPool2d(2,2)
        
        self.layer_8 = nn.Conv2d(in_channels=256,out_channels=256,kernel_size=3,
                                 stride=1,padding=2)
        self.act_8 = nn.LeakyReLU(0.1)
        self.conv2_bn8 = nn.BatchNorm2d(256)
        
        
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        
        self.fc_layer_1 = nn.Linear(256,10)
        self.act_9 = nn.LeakyReLU(0.1)
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        
        

    def forward(self, x):
        out = self.layer_1(x)
        out = self.act_1(out)
        for module in list(self.modules())[2:-2]:
            out = module(out)
        out = torch.flatten(out,1)
        for module in list(self.modules())[-2:]:
            out = module(out)
        return out

# %%
model = Model()
model = model.cuda()
criterion = nn.CrossEntropyLoss().cuda()

# %%
# for name, param in model.named_parameters():
#     if param.requires_grad:
#         print (name, param.data)

# %%
from torchsummary import summary
summary(model,(3,96,96))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 48, 48]           9,472
#          LeakyReLU-2           [-1, 64, 48, 48]               0
#          LeakyReLU-3           [-1, 64, 48, 48]               0
#        BatchNorm2d-4           [-1, 64, 48, 48]             128
#          MaxPool2d-5           [-1, 64, 24, 24]               0
#             Conv2d-6           [-1, 64, 26, 26]          36,928
#          LeakyReLU-7           [-1, 64, 26, 26]               0
#        BatchNorm2d-8           [-1, 64, 26, 26]             128
#             Conv2d-9          [-1, 128, 28, 28]          73,856
#         LeakyReLU-10          [-1, 128, 28, 28]               0
#       BatchNorm2d-11          [-1, 128, 28, 28]             256
#            Conv2d-12          [-1, 128, 26, 26]         147,584
#         LeakyReLU-13          [-1, 128, 26, 26]               0
#       BatchNorm2d-14          [-1, 128, 26, 26]             256
#            Conv2d-15          [-1, 128, 28, 28]         147,584
#         LeakyReLU-16          [-1, 128, 28, 28]               0
#       BatchNorm2d-17          [-1, 128, 28, 28]             256
#            Conv2d-18          [-1, 256, 30, 30]         295,168
#         LeakyReLU-19          [-1, 256, 30, 30]               0
#       BatchNorm2d-20          [-1, 256, 30, 30]             512
#            Conv2d-21          [-1, 256, 28, 28]         590,080
#         LeakyReLU-22          [-1, 256, 28, 28]               0
#       BatchNorm2d-23          [-1, 256, 28, 28]             512
#         MaxPool2d-24          [-1, 256, 14, 14]               0
#            Conv2d-25          [-1, 256, 16, 16]         590,080
#         LeakyReLU-26          [-1, 256, 16, 16]               0
#       BatchNorm2d-27          [-1, 256, 16, 16]             512
# AdaptiveAvgPool2d-28            [-1, 256, 1, 1]               0
#            Linear-29                   [-1, 10]           2,570
#         LeakyReLU-30                   [-1, 10]               0
# ================================================================
# Total params: 1,895,882
# Trainable params: 1,895,882
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.11
# Forward/backward pass size (MB): 24.10
# Params size (MB): 7.23
# Estimated Total Size (MB): 31.44
# ----------------------------------------------------------------

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30)

# %%
saving_path="/home/jupyter-deeplearning/res_model"
trn_loss_list = []
val_loss_list = []
val_acc_list = []
total_epoch=120
model_char="2.0"
model_name=""
patience=10
start_early_stop_check=0
saving_start_epoch=10

for epoch in range(total_epoch):
    trn_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        if torch.cuda.is_available():
            inputs=inputs.cuda()
            labels=labels.cuda()
        # grad init
        optimizer.zero_grad()
        # forward propagation
        output= model(inputs)
        # calculate loss
        loss=criterion(output, labels)
        # back propagation 
        loss.backward()
        # weight update
        optimizer.step()
        
        # trn_loss summary
        trn_loss += loss.item()
        # del (memory issue)
        del loss
        del output
    with torch.no_grad():
        val_loss = 0.0
        cor_match = 0
        for j, val in enumerate(test_loader):
            val_x, val_label = val
            if torch.cuda.is_available():
                val_x = val_x.cuda()
                val_label =val_label.cuda()
            val_output = model(val_x)
            v_loss = criterion(val_output, val_label)
            val_loss += v_loss
            _, predicted=torch.max(val_output,1)
            cor_match+=np.count_nonzero(predicted.cpu().detach()==val_label.cpu().detach())
    del val_output
    del v_loss
    del predicted
    
    scheduler.step()
    
    
    
    trn_loss_list.append(trn_loss/len(train_loader))
    val_loss_list.append(val_loss/len(test_loader))
    val_acc=cor_match/(len(test_loader)*batch_size)
    val_acc_list.append(val_acc)
    now = time.localtime()
    print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))

    print("epoch: {}/{} | trn loss: {:.4f} | val loss: {:.4f} | val accuracy: {:.4f}% \n".format(
                epoch+1, total_epoch, trn_loss / len(train_loader), val_loss / len(test_loader), val_acc*100
            ))
    
    
    if epoch+1>2:
        if val_loss_list[-1]>val_loss_list[-2]:
            start_early_stop_check=1
    else:
        val_loss_min=val_loss_list[-1]
        
    if start_early_stop_check:
        early_stop_temp=val_loss_list[-patience:]
        if all(early_stop_temp[i]<early_stop_temp[i+1] for i in range (len(early_stop_temp)-1)):
            print("Early stop!")
            break
            
    if epoch+1>saving_start_epoch:
        if val_loss_list[-1]<val_loss_min:
            if os.path.isfile(model_name):
                os.remove(model_name)
            val_loss_min=val_loss_list[-1]
            model_name=saving_path+"Custom_model_"+model_char+"_{:.3f}".format(val_loss_min)
            torch.save(model, model_name)
            print("Model replaced and saved as ",model_name)
# Out:
# 2020/11/22 18:30:19
# epoch: 1/120 | trn loss: 1.8541 | val loss: 1.7218 | val accuracy: 37.0893%
#
# 2020/11/22 18:30:50
# epoch: 2/120 | trn loss: 1.5976 | val loss: 1.5650 | val accuracy: 43.0439%
#
# 2020/11/22 18:31:21
# epoch: 3/120 | trn loss: 1.4411 | val loss: 1.4180 | val accuracy: 49.2188%
#
# 2020/11/22 18:31:53
# epoch: 4/120 | trn loss: 1.3249 | val loss: 1.3610 | val accuracy: 51.4774%
#
# 2020/11/22 18:32:24
# epoch: 5/120 | trn loss: 1.2143 | val loss: 1.2842 | val accuracy: 54.1366%
#
# 2020/11/22 18:32:56
# epoch: 6/120 | trn loss: 1.1312 | val loss: 1.2858 | val accuracy: 54.3119%
#
# 2020/11/22 18:33:28
# epoch: 7/120 | trn loss: 1.0660 | val loss: 1.1868 | val accuracy: 58.1130%
#
# 2020/11/22 18:33:59
# epoch: 8/120 | trn loss: 0.9974 | val loss: 1.1777 | val accuracy: 58.6488%
#
# 2020/11/22 18:34:30
# epoch: 9/120 | trn loss: 0.9337 | val loss: 1.1659 | val accuracy: 60.0611%
#
# 2020/11/22 18:35:02
# epoch: 10/120 | trn loss: 0.8849 | val loss: 1.1700 | val accuracy: 59.2398%
#
# 2020/11/22 18:35:33
# epoch: 11/120 | trn loss: 0.8443 | val loss: 1.1350 | val accuracy: 60.6771%
#
# Model replaced and saved as  /home/jupyter-deeplearning/res_modelCustom_model_2.0_1.135
# 2020/11/22 18:36:04
# epoch: 12/120 | trn loss: 0.7963 | val loss: 1.1540 | val accuracy: 60.6771%
#
# 2020/11/22 18:36:36
# epoch: 13/120 | trn loss: 0.7528 | val loss: 1.1505 | val accuracy: 60.8123%
#
# 2020/11/22 18:37:07
# epoch: 14/120 | trn loss: 0.7299 | val loss: 1.1406 | val accuracy: 61.5485%
#
# 2020/11/22 18:37:38
# epoch: 15/120 | trn loss: 0.6971 | val loss: 1.1312 | val accuracy: 62.2947%
#
# Model replaced and saved as  /home/jupyter-deeplearning/res_modelCustom_model_2.0_1.131
# 2020/11/22 18:38:09
# epoch: 16/120 | trn loss: 0.6596 | val loss: 1.1527 | val accuracy: 61.7188%
#
# 2020/11/22 18:38:40
# epoch: 17/120 | trn loss: 0.6361 | val loss: 1.1651 | val accuracy: 61.9942%
#
# 2020/11/22 18:39:12
# epoch: 18/120 | trn loss: 0.6125 | val loss: 1.1233 | val accuracy: 62.8706%
#
# Model replaced and saved as  /home/jupyter-deeplearning/res_modelCustom_model_2.0_1.123
# 2020/11/22 18:39:43
# epoch: 19/120 | trn loss: 0.5927 | val loss: 1.1329 | val accuracy: 62.7704%
#
# 2020/11/22 18:40:14
# epoch: 20/120 | trn loss: 0.5803 | val loss: 1.1613 | val accuracy: 62.7604%
#
# 2020/11/22 18:40:46
# epoch: 21/120 | trn loss: 0.5664 | val loss: 1.1296 | val accuracy: 63.7019%
#
# 2020/11/22 18:41:17
# epoch: 22/120 | trn loss: 0.5430 | val loss: 1.1584 | val accuracy: 63.4265%
#
# 2020/11/22 18:41:48
# epoch: 23/120 | trn loss: 0.5394 | val loss: 1.1342 | val accuracy: 63.7019%
#
# 2020/11/22 18:42:19
# epoch: 24/120 | trn loss: 0.5252 | val loss: 1.1402 | val accuracy: 63.6919%
#
# 2020/11/22 18:42:51
# epoch: 25/120 | trn loss: 0.5157 | val loss: 1.1170 | val accuracy: 64.5583%
#
# Model replaced and saved as  /home/jupyter-deeplearning/res_modelCustom_model_2.0_1.117
# 2020/11/22 18:43:22
# epoch: 26/120 | trn loss: 0.4984 | val loss: 1.1519 | val accuracy: 63.7470%
#
# 2020/11/22 18:43:53
# epoch: 27/120 | trn loss: 0.4902 | val loss: 1.1729 | val accuracy: 63.8171%
#
# 2020/11/22 18:44:24
# epoch: 28/120 | trn loss: 0.4854 | val loss: 1.1352 | val accuracy: 65.0942%
#
# 2020/11/22 18:44:56
# epoch: 29/120 | trn loss: 0.4802 | val loss: 1.1357 | val accuracy: 64.4231%
#
# 2020/11/22 18:45:27
# epoch: 30/120 | trn loss: 0.4684 | val loss: 1.2004 | val accuracy: 63.4766%
#
# 2020/11/22 18:45:58
# epoch: 31/120 | trn loss: 0.3619 | val loss: 1.0347 | val accuracy: 67.8435%
#
# Model replaced and saved as  /home/jupyter-deeplearning/res_modelCustom_model_2.0_1.035
# 2020/11/22 18:46:30
# epoch: 32/120 | trn loss: 0.3189 | val loss: 1.0601 | val accuracy: 67.2726%
#
# 2020/11/22 18:47:02
# epoch: 33/120 | trn loss: 0.3077 | val loss: 1.0720 | val accuracy: 67.1775%
#
# 2020/11/22 18:47:33
# epoch: 34/120 | trn loss: 0.3006 | val loss: 1.0682 | val accuracy: 67.6082%
#
# 2020/11/22 18:48:04
# epoch: 35/120 | trn loss: 0.2898 | val loss: 1.0879 | val accuracy: 67.2426%
#
# 2020/11/22 18:48:35
# epoch: 36/120 | trn loss: 0.2856 | val loss: 1.0897 | val accuracy: 67.5881%
#
# 2020/11/22 18:49:07
# epoch: 37/120 | trn loss: 0.2802 | val loss: 1.0743 | val accuracy: 67.7183%
#
# 2020/11/22 18:49:39
# epoch: 38/120 | trn loss: 0.2752 | val loss: 1.0746 | val accuracy: 67.7985%
#
# 2020/11/22 18:50:10
# epoch: 39/120 | trn loss: 0.2813 | val loss: 1.0715 | val accuracy: 68.2742%
#
# 2020/11/22 18:50:41
# epoch: 40/120 | trn loss: 0.2716 | val loss: 1.0983 | val accuracy: 67.3127%
#
# 2020/11/22 18:51:12
# epoch: 41/120 | trn loss: 0.2737 | val loss: 1.1029 | val accuracy: 67.7634%
#
# 2020/11/22 18:51:43
# epoch: 42/120 | trn loss: 0.2716 | val loss: 1.1043 | val accuracy: 67.6232%
#
# 2020/11/22 18:52:15
# epoch: 43/120 | trn loss: 0.2609 | val loss: 1.0980 | val accuracy: 67.9938%
#
# 2020/11/22 18:52:46
# epoch: 44/120 | trn loss: 0.2638 | val loss: 1.1155 | val accuracy: 67.6783%
#
# 2020/11/22 18:53:17
# epoch: 45/120 | trn loss: 0.2567 | val loss: 1.1196 | val accuracy: 67.5230%
#
# 2020/11/22 18:53:48
# epoch: 46/120 | trn loss: 0.2523 | val loss: 1.1179 | val accuracy: 67.5681%
#
# 2020/11/22 18:54:19
# epoch: 47/120 | trn loss: 0.2525 | val loss: 1.1071 | val accuracy: 67.8886%
#
# 2020/11/22 18:54:51
# epoch: 48/120 | trn loss: 0.2502 | val loss: 1.1087 | val accuracy: 67.4930%
#
# 2020/11/22 18:55:22
# epoch: 49/120 | trn loss: 0.2499 | val loss: 1.1263 | val accuracy: 67.6432%
#
# 2020/11/22 18:55:53
# epoch: 50/120 | trn loss: 0.2491 | val loss: 1.1287 | val accuracy: 67.3878%
#
# 2020/11/22 18:56:25
# epoch: 51/120 | trn loss: 0.2471 | val loss: 1.1285 | val accuracy: 67.5030%
#
# 2020/11/22 18:56:56
# epoch: 52/120 | trn loss: 0.2433 | val loss: 1.1350 | val accuracy: 67.8235%
#
# 2020/11/22 18:57:27
# epoch: 53/120 | trn loss: 0.2415 | val loss: 1.1365 | val accuracy: 67.3778%
#
# 2020/11/22 18:57:58
# epoch: 54/120 | trn loss: 0.2421 | val loss: 1.1291 | val accuracy: 67.9738%
#
# 2020/11/22 18:58:30
# epoch: 55/120 | trn loss: 0.2356 | val loss: 1.1138 | val accuracy: 67.8986%
#
# 2020/11/22 18:59:01
# epoch: 56/120 | trn loss: 0.2327 | val loss: 1.1485 | val accuracy: 67.6382%
#
# 2020/11/22 18:59:33
# epoch: 57/120 | trn loss: 0.2332 | val loss: 1.1473 | val accuracy: 67.0373%
#
# 2020/11/22 19:00:04
# epoch: 58/120 | trn loss: 0.2361 | val loss: 1.1404 | val accuracy: 67.5481%
#
# 2020/11/22 19:00:35
# epoch: 59/120 | trn loss: 0.2348 | val loss: 1.1225 | val accuracy: 67.7284%
#
# 2020/11/22 19:01:06
# epoch: 60/120 | trn loss: 0.2355 | val loss: 1.1380 | val accuracy: 67.8486%
#
# 2020/11/22 19:01:37
# epoch: 61/120 | trn loss: 0.2233 | val loss: 1.1120 | val accuracy: 68.4846%
#
# 2020/11/22 19:02:08
# epoch: 62/120 | trn loss: 0.2208 | val loss: 1.1109 | val accuracy: 68.3243%
#
# 2020/11/22 19:02:40
# epoch: 63/120 | trn loss: 0.2167 | val loss: 1.1022 | val accuracy: 68.4095%
#
# 2020/11/22 19:03:11
# epoch: 64/120 | trn loss: 0.2170 | val loss: 1.1134 | val accuracy: 68.4245%
#
# 2020/11/22 19:03:42
# epoch: 65/120 | trn loss: 0.2130 | val loss: 1.1073 | val accuracy: 68.6799%
#
# 2020/11/22 19:04:13
# epoch: 66/120 | trn loss: 0.2119 | val loss: 1.0984 | val accuracy: 68.9603%
#
# 2020/11/22 19:04:44
# epoch: 67/120 | trn loss: 0.2119 | val loss: 1.1121 | val accuracy: 68.0940%
#
# 2020/11/22 19:05:16
# epoch: 68/120 | trn loss: 0.2088 | val loss: 1.1180 | val accuracy: 68.3794%
#
# 2020/11/22 19:05:47
# epoch: 69/120 | trn loss: 0.2081 | val loss: 1.1057 | val accuracy: 68.5697%
#
# 2020/11/22 19:06:18
# epoch: 70/120 | trn loss: 0.2125 | val loss: 1.1248 | val accuracy: 68.2642%
#
# 2020/11/22 19:06:49
# epoch: 71/120 | trn loss: 0.2136 | val loss: 1.1040 | val accuracy: 68.4195%
#
# 2020/11/22 19:07:21
# epoch: 72/120 | trn loss: 0.2148 | val loss: 1.1042 | val accuracy: 68.9002%
#
# 2020/11/22 19:07:52
# epoch: 73/120 | trn loss: 0.2106 | val loss: 1.0983 | val accuracy: 68.5397%
#
# 2020/11/22 19:08:23
# epoch: 74/120 | trn loss: 0.2075 | val loss: 1.0861 | val accuracy: 68.7851%
#
# 2020/11/22 19:08:55
# epoch: 75/120 | trn loss: 0.2111 | val loss: 1.1089 | val accuracy: 68.5296%
#
# 2020/11/22 19:09:26
# epoch: 76/120 | trn loss: 0.2106 | val loss: 1.1067 | val accuracy: 68.5347%
#
# 2020/11/22 19:09:57
# epoch: 77/120 | trn loss: 0.2056 | val loss: 1.0894 | val accuracy: 68.6048%
#
# 2020/11/22 19:10:28
# epoch: 78/120 | trn loss: 0.2081 | val loss: 1.1047 | val accuracy: 68.1841%
#
# 2020/11/22 19:10:59
# epoch: 79/120 | trn loss: 0.2053 | val loss: 1.1112 | val accuracy: 68.2592%
# 2020/11/22 19:11:31
# epoch: 80/120 | trn loss: 0.2044 | val loss: 1.1136 | val accuracy: 68.6899%
#
# 2020/11/22 19:12:02
# epoch: 81/120 | trn loss: 0.2075 | val loss: 1.1246 | val accuracy: 67.9537%
#
# 2020/11/22 19:12:33
# epoch: 82/120 | trn loss: 0.2081 | val loss: 1.1219 | val accuracy: 68.6148%
#
# 2020/11/22 19:13:04
# epoch: 83/120 | trn loss: 0.2041 | val loss: 1.1293 | val accuracy: 67.8536%
#
# 2020/11/22 19:13:35
# epoch: 84/120 | trn loss: 0.2109 | val loss: 1.1046 | val accuracy: 68.4696%
#
# 2020/11/22 19:14:07
# epoch: 85/120 | trn loss: 0.2050 | val loss: 1.1281 | val accuracy: 68.2492%
#
# 2020/11/22 19:14:38
# epoch: 86/120 | trn loss: 0.2003 | val loss: 1.1134 | val accuracy: 68.6699%
#
# 2020/11/22 19:15:10
# epoch: 87/120 | trn loss: 0.2033 | val loss: 1.1240 | val accuracy: 68.1691%
#
# 2020/11/22 19:15:41
# epoch: 88/120 | trn loss: 0.2045 | val loss: 1.1168 | val accuracy: 68.2843%
#
# 2020/11/22 19:16:12
# epoch: 89/120 | trn loss: 0.2016 | val loss: 1.1179 | val accuracy: 68.3594%
#
# 2020/11/22 19:16:44
# epoch: 90/120 | trn loss: 0.2021 | val loss: 1.1064 | val accuracy: 68.8001%
#
# 2020/11/22 19:17:15
# epoch: 91/120 | trn loss: 0.2017 | val loss: 1.1287 | val accuracy: 68.4145%
#
# 2020/11/22 19:17:47
# epoch: 92/120 | trn loss: 0.1995 | val loss: 1.1171 | val accuracy: 68.5847%
#
# 2020/11/22 19:18:18
# epoch: 93/120 | trn loss: 0.2003 | val loss: 1.1100 | val accuracy: 68.7500%
#
# 2020/11/22 19:18:50
# epoch: 94/120 | trn loss: 0.2018 | val loss: 1.1125 | val accuracy: 68.4395%
#
# 2020/11/22 19:19:22
# epoch: 95/120 | trn loss: 0.2028 | val loss: 1.1284 | val accuracy: 68.3293%
#
# 2020/11/22 19:19:54
# epoch: 96/120 | trn loss: 0.2047 | val loss: 1.1155 | val accuracy: 68.5847%
#
# 2020/11/22 19:20:26
# epoch: 97/120 | trn loss: 0.2037 | val loss: 1.1206 | val accuracy: 68.2292%
#
# 2020/11/22 19:20:58
# epoch: 98/120 | trn loss: 0.2033 | val loss: 1.1039 | val accuracy: 68.4545%
#
# 2020/11/22 19:21:30
# epoch: 99/120 | trn loss: 0.2000 | val loss: 1.0886 | val accuracy: 68.4645%
#
# 2020/11/22 19:22:01
# epoch: 100/120 | trn loss: 0.1990 | val loss: 1.1157 | val accuracy: 68.3544%
#
# 2020/11/22 19:22:33
# epoch: 101/120 | trn loss: 0.2030 | val loss: 1.1057 | val accuracy: 68.1190%
#
# 2020/11/22 19:23:05
# epoch: 102/120 | trn loss: 0.2014 | val loss: 1.1064 | val accuracy: 68.7500%
#
# 2020/11/22 19:23:38
# epoch: 103/120 | trn loss: 0.2031 | val loss: 1.1075 | val accuracy: 68.5146%
#
# 2020/11/22 19:24:10
# epoch: 104/120 | trn loss: 0.2011 | val loss: 1.0996 | val accuracy: 68.4595%
#
# 2020/11/22 19:24:41
# epoch: 105/120 | trn loss: 0.2064 | val loss: 1.1174 | val accuracy: 68.1240%
#
# 2020/11/22 19:25:13
# epoch: 106/120 | trn loss: 0.2031 | val loss: 1.0958 | val accuracy: 68.7800%
#
# 2020/11/22 19:25:45
# epoch: 107/120 | trn loss: 0.2001 | val loss: 1.1071 | val accuracy: 68.5497%
#
# 2020/11/22 19:26:17
# epoch: 108/120 | trn loss: 0.2017 | val loss: 1.1349 | val accuracy: 67.9788%
#
# 2020/11/22 19:26:50
# epoch: 109/120 | trn loss: 0.2019 | val loss: 1.1208 | val accuracy: 68.0539%
#
# 2020/11/22 19:27:22
# epoch: 110/120 | trn loss: 0.1989 | val loss: 1.1112 | val accuracy: 68.5397%
#
# 2020/11/22 19:27:54
# epoch: 111/120 | trn loss: 0.1980 | val loss: 1.1144 | val accuracy: 68.7200%
#
# 2020/11/22 19:28:26
# epoch: 112/120 | trn loss: 0.2010 | val loss: 1.1148 | val accuracy: 68.7450%
#
# 2020/11/22 19:28:58
# epoch: 113/120 | trn loss: 0.2017 | val loss: 1.1157 | val accuracy: 68.5347%
#
# 2020/11/22 19:29:30
# epoch: 114/120 | trn loss: 0.2003 | val loss: 1.1051 | val accuracy: 68.6949%
#
# 2020/11/22 19:30:03
# epoch: 115/120 | trn loss: 0.1996 | val loss: 1.1171 | val accuracy: 68.2843%
#
# 2020/11/22 19:30:36
# epoch: 116/120 | trn loss: 0.2017 | val loss: 1.1069 | val accuracy: 68.7450%
#
# 2020/11/22 19:31:09
# epoch: 117/120 | trn loss: 0.2002 | val loss: 1.1106 | val accuracy: 68.3494%
#
# 2020/11/22 19:31:42
# epoch: 118/120 | trn loss: 0.2024 | val loss: 1.1145 | val accuracy: 68.4095%
#
# 2020/11/22 19:32:15
# epoch: 119/120 | trn loss: 0.2034 | val loss: 1.1314 | val accuracy: 68.9353%
#
# 2020/11/22 19:32:49
# epoch: 120/120 | trn loss: 0.1995 | val loss: 1.1061 | val accuracy: 68.4796%

# %%
dataset = datasets.ImageFolder(
        train_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
        transforms.Resize(120),    
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
for _ in range (19):
    aug_data = datasets.ImageFolder(
        train_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
        transforms.Resize(120),    
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
    dataset=torch.utils.data.ConcatDataset([dataset,aug_data])
valset = datasets.ImageFolder(
        test_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
        transforms.Resize(120),
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
for _ in range (19):
    aug_data = datasets.ImageFolder(
        test_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
        transforms.Resize(120),    
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
    valset=torch.utils.data.ConcatDataset([valset,aug_data])

train_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=True,
        num_workers=8, pin_memory=True,drop_last=True)

test_loader = torch.utils.data.DataLoader(
        valset, batch_size=batch_size, shuffle=True,
        num_workers=8, pin_memory=True,drop_last=True)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20)

# %%
#fine tuning
saving_path="/home/jupyter-deeplearning/res_model"
total_epoch=80
model_char="2.0"
model_name=""
patience=10
start_early_stop_check=0
saving_start_epoch=10

for epoch in range(total_epoch):
    trn_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        if torch.cuda.is_available():
            inputs=inputs.cuda()
            labels=labels.cuda()
        # grad init
        optimizer.zero_grad()
        # forward propagation
        output= model(inputs)
        # calculate loss
        loss=criterion(output, labels)
        # back propagation 
        loss.backward()
        # weight update
        optimizer.step()
        
        # trn_loss summary
        trn_loss += loss.item()
        # del (memory issue)
        del loss
        del output
    with torch.no_grad():
        val_loss = 0.0
        cor_match = 0
        for j, val in enumerate(test_loader):
            val_x, val_label = val
            if torch.cuda.is_available():
                val_x = val_x.cuda()
                val_label =val_label.cuda()
            val_output = model(val_x)
            v_loss = criterion(val_output, val_label)
            val_loss += v_loss
            _, predicted=torch.max(val_output,1)
            cor_match+=np.count_nonzero(predicted.cpu().detach()==val_label.cpu().detach())
    del val_output
    del v_loss
    del predicted
    
    scheduler.step()
    
    
    
    trn_loss_list.append(trn_loss/len(train_loader))
    val_loss_list.append(val_loss/len(test_loader))
    val_acc=cor_match/(len(test_loader)*batch_size)
    val_acc_list.append(val_acc)
    now = time.localtime()
    print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))

    print("epoch: {}/{} | trn loss: {:.4f} | val loss: {:.4f} | val accuracy: {:.4f}% \n".format(
                epoch+1, total_epoch, trn_loss / len(train_loader), val_loss / len(test_loader), val_acc*100
            ))
    
    
    if epoch+1>2:
        if val_loss_list[-1]>val_loss_list[-2]:
            start_early_stop_check=1
    else:
        val_loss_min=val_loss_list[-1]
        
    if start_early_stop_check:
        early_stop_temp=val_loss_list[-patience:]
        if all(early_stop_temp[i]<early_stop_temp[i+1] for i in range (len(early_stop_temp)-1)):
            print("Early stop!")
            break
            
    if epoch+1>saving_start_epoch:
        if val_loss_list[-1]<val_loss_min:
            if os.path.isfile(model_name):
                os.remove(model_name)
            val_loss_min=val_loss_list[-1]
            model_name=saving_path+"Custom_model_"+model_char+"_{:.3f}".format(val_loss_min)
            torch.save(model, model_name)
            print("Model replaced and saved as ",model_name)

# %%
plt.figure(figsize=(15,15))
plt.ylabel("val_accuracy")
plt.xlabel("epoch")
plt.plot(val_acc_list)
plt.grid()

# %%
train_path_path= "../data/train"
test_path_path= "../data/train"

# %%
dataset = datasets.ImageFolder(
        train_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
        transforms.Resize(120),    
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
for _ in range (19):
    aug_data = datasets.ImageFolder(
        train_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
        transforms.Resize(120),    
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
    dataset=torch.utils.data.ConcatDataset([dataset,aug_data])
valset = datasets.ImageFolder(
        test_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
        transforms.Resize(120),
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
for _ in range (19):
    aug_data = datasets.ImageFolder(
        test_path_path,
        transforms.Compose([
        transforms.RandomRotation(degrees=45),
        transforms.Resize(120),    
        transforms.ColorJitter(.3,.3,.3,.3),
        transforms.RandomHorizontalFlip(),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
    valset=torch.utils.data.ConcatDataset([valset,aug_data])

train_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=True,
        num_workers=8, pin_memory=True,drop_last=True)

test_loader = torch.utils.data.DataLoader(
        valset, batch_size=batch_size, shuffle=True,
        num_workers=8, pin_memory=True,drop_last=True)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20)

# %%
model.train()

# %%
#train val set
saving_path="/home/jupyter-deeplearning/res_model"
total_epoch=80
model_char="2.0"
model_name=""
patience=10
start_early_stop_check=0
saving_start_epoch=10

for epoch in range(total_epoch):
    trn_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        if torch.cuda.is_available():
            inputs=inputs.cuda()
            labels=labels.cuda()
        # grad init
        optimizer.zero_grad()
        # forward propagation
        output= model(inputs)
        # calculate loss
        loss=criterion(output, labels)
        # back propagation 
        loss.backward()
        # weight update
        optimizer.step()
        
        # trn_loss summary
        trn_loss += loss.item()
        # del (memory issue)
        del loss
        del output
    with torch.no_grad():
        val_loss = 0.0
        cor_match = 0
        for j, val in enumerate(test_loader):
            val_x, val_label = val
            if torch.cuda.is_available():
                val_x = val_x.cuda()
                val_label =val_label.cuda()
            val_output = model(val_x)
            v_loss = criterion(val_output, val_label)
            val_loss += v_loss
            _, predicted=torch.max(val_output,1)
            cor_match+=np.count_nonzero(predicted.cpu().detach()==val_label.cpu().detach())
    del val_output
    del v_loss
    del predicted
    
    scheduler.step()
    
    
    
    trn_loss_list.append(trn_loss/len(train_loader))
    val_loss_list.append(val_loss/len(test_loader))
    val_acc=cor_match/(len(test_loader)*batch_size)
    val_acc_list.append(val_acc)
    now = time.localtime()
    print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))

    print("epoch: {}/{} | trn loss: {:.4f} | val loss: {:.4f} | val accuracy: {:.4f}% \n".format(
                epoch+1, total_epoch, trn_loss / len(train_loader), val_loss / len(test_loader), val_acc*100
            ))
    
    
    if epoch+1>2:
        if val_loss_list[-1]>val_loss_list[-2]:
            start_early_stop_check=1
    else:
        val_loss_min=val_loss_list[-1]
        
    if start_early_stop_check:
        early_stop_temp=val_loss_list[-patience:]
        if all(early_stop_temp[i]<early_stop_temp[i+1] for i in range (len(early_stop_temp)-1)):
            print("Early stop!")
            break
            
    if epoch+1>saving_start_epoch:
        if val_loss_list[-1]<val_loss_min:
            if os.path.isfile(model_name):
                os.remove(model_name)
            val_loss_min=val_loss_list[-1]
            model_name=saving_path+"Custom_model_"+model_char+"_{:.3f}".format(val_loss_min)
            torch.save(model, model_name)
            print("Model replaced and saved as ",model_name)

# %%
plt.figure(figsize=(15,15))
plt.ylabel("val_accuracy")
plt.xlabel("epoch")
plt.plot(val_acc_list)
plt.grid()

# %%
# val_acc_list=np.array(val_acc_list)
# np.savetxt("ver_2.0.txt", val_acc_list, delimiter=',')

# %% [markdown]
# ### Evaluation

# %%
import torch
import pandas as pd
import argparse
import time
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader

# %%
model.eval()
# Out:
# Model(
#   (layer_1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (act_1): LeakyReLU(negative_slope=0.1)
#   (conv2_bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (max_1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (layer_2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (act_2): LeakyReLU(negative_slope=0.1)
#   (conv2_bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer_3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (act_3): LeakyReLU(negative_slope=0.1)
#   (conv2_bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer_4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (act_4): LeakyReLU(negative_slope=0.1)
#   (conv2_bn4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer_5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (act_5): LeakyReLU(negative_slope=0.1)
#   (conv2_bn5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer_6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (act_6): LeakyReLU(negative_slope=0.1)
#   (conv2_bn6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer_7): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#   (act_7): LeakyReLU(negative_slope=0.1)
#   (conv2_bn7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (max_2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (layer_8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (act_8): LeakyReLU(negative_slope=0.1)
#   (conv2_bn8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc_layer_1): Linear(in_features=256, out_features=10, bias=True)
#   (act_9): LeakyReLU(negative_slope=0.1)
# )

# %%
normalize = transforms.Normalize(mean=[0.507, 0.487, 0.441],
                                     std=[0.267, 0.256, 0.276])
test_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize
    ])

# %%
test_dataset = torchvision.datasets.ImageFolder('./data/test', transform=test_transform)

# %%
test_loader = DataLoader(test_dataset, batch_size=batch_size, num_workers=4, shuffle=False)

# %%
Category = []
for input, _ in test_loader:
    input = input.cuda()
    output = model(input)
    output = torch.argmax(output, dim=1)
    Category = Category + output.tolist()

# %%
Id = list(range(0, 8000))
samples = {
   'Id': Id,
   'Category': Category 
}
df = pd.DataFrame(samples, columns=['Id', 'Category'])

df.to_csv('submission_2.0_2.csv', index=False)
print('Done!!')
# Out:
# Done!!
